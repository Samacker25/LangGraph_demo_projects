# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
load_dotenv()
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.7)

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'pizza'}, config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why did the pizza get a job?\n\nBecause it kneaded the dough!',
#  'explanation': 'This is a classic pun! The humor comes from the phrase "**kneaded the dough**," which has two different meanings that sound almost identical:\n\n1.  **"Kneaded the dough" (pizza-making context):** When you make pizza (or bread), you **knead** the **dough**. This is the process of pressing, folding, and stretching the mixture of flour and water to develop its gluten and give it texture. So, a pizza (or the ingredients for it) is inherently associated with the act of kneading dough.\n\n2.  **"Needed the dough" (slang context):** This is where the pun kicks in. The word "**kneaded**" sounds exactly like "**needed**" (past tense of \'to need,\' meaning to require something). And "**dough**" is a common slang term for **money**. So, "needed the dough" means "needed money."\n\nThe joke works because it gives the inanimate pizza a human-like motivation for getting a job (needing money), but frames it using a phrase that literally describes a process involved in making pizza. The unexpected twist and the clever play on words are what make it funny.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\n\nBecause it kneaded the dough!', 'explanation': 'This is a classic pun! The humor comes from the phrase "**kneaded the dough**," which has two different meanings that sound almost identical:\n\n1.  **"Kneaded the dough" (pizza-making context):** When you make pizza (or bread), you **knead** the **dough**. This is the process of pressing, folding, and stretching the mixture of flour and water to develop its gluten and give it texture. So, a pizza (or the ingredients for it) is inherently associated with the act of kneading dough.\n\n2.  **"Needed the dough" (slang context):** This is where the pun kicks in. The word "**kneaded**" sounds exactly like "**needed**" (past tense of \'to need,\' meaning to require something). And "**dough**" is a common slang term for **money**. So, "needed the dough" means "needed money."\n\nThe joke works because it gives the inanimate pizza a human-like motivation for getting a job (needing money), but frames it using a phrase that literally describes a process involved in making pizza. The unexpected twist and the clever play on words are what make it funny.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a050-07a4-6f4f-8002-241c88af6094'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-03-27T17:47:19.641479+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a04f-cb7e-655b-8001-d7c1cf2b0f82'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\n\nBecause it kneaded the dough!', 'explanation': 'This is a classic pun! The humor comes from the phrase "**kneaded the dough**," which has two different meanings that sound almost identical:\n\n1.  **"Kneaded the dough" (pizza-making context):** When you make pizza (or bread), you **knead** the **dough**. This is the process of pressing, folding, and stretching the mixture of flour and water to develop its gluten and give it texture. So, a pizza (or the ingredients for it) is inherently associated with the act of kneading dough.\n\n2.  **"Needed the dough" (slang context):** This is where the pun kicks in. The word "**kneaded**" sounds exactly like "**needed**" (past tense of \'to need,\' meaning to require something). And "**dough**" is a common slang term for **money**. So, "needed the dough" means "needed money."\n\nThe joke works because it gives the inanimate pizza a human-like motivation for getting a job (needing money), but frames it using a phrase that literally describes a process involved in making pizza. The unexpected twist and the clever play on words are what make it funny.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a050-07a4-6f4f-8002-241c88af6094'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-03-27T17:47:19.641479+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a04f-cb7e-655b-8001-d7c1cf2b0f82'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\n\nBecause it kneaded the dough!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a04f-cb7e-655b-8001-d7c1cf2b0f82'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-03-27T17:47:13.334204+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a04f-6ac9-6f7d-8000-562f0cf0780b'}}, tasks=(PregelTask(id='6f1e42ab-3104-96e7-d068-06e55e7cc23c', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This is a classic pun! The humor comes from the phrase "**kneaded the dough**," which has two different meanings that sound almost identical:\n\n1.  **"Kneaded the dough" (pizza-making context):** When you make pizza (or bread), you **knead** the **dough**. This is the process of pressing, folding, and stretching the mixture of flour and water to develop its gluten and give it texture. So, a pizza (or the ingredients for it) is inherently associated with the act of kneading dough.\n\n2.  **"Needed the dough" (slang context):** This is where the pun kicks in. The word "**kneaded**" sounds exactly like "**needed**" (past tense of \'to need,\' meaning to require something). And "**dough**" is a common slang term for **money**. So, "needed the dough" means "needed money."\n\nThe joke works because it gives the inanimate pizza a human-like motivation for getting a job (needing money), but frames it using a phrase that literally describes a process involved in making pizza. The unexpected twist and the clever play on words are what make it funny.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a04f-6ac9-6f7d-8000-562f0cf0780b'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-03-27T17:47:03.193996+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a04f-6abd-6a59-bfff-1d075d479032'}}, tasks=(PregelTask(id='bf53d956-c17f-91ab-f620-2ca3fb4f2f1f', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza get a job?\n\nBecause it kneaded the dough!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a04f-6abd-6a59-bfff-1d075d479032'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-03-27T17:47:03.188949+00:00', parent_config=None, tasks=(PregelTask(id='9abb097c-4c7a-e990-5d0b-efe986401adb', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'pasta'}, config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the pasta break up with the sauce?\n\nBecause he was an **impasta**!',
#  'explanation': 'This is a classic pun-based joke! Here\'s the breakdown:\n\n1.  **The Play on Words:** The humor comes from the word "**impasta**," which is a clever play on the word "**imposter**."\n\n2.  **What an "Imposter" Is:** An imposter is someone who pretends to be someone else, or who is not genuine; a fake or a deceiver. In a relationship, discovering your partner is an imposter would certainly be a valid reason for a breakup!\n\n3.  **The "Pasta" Connection:** The joke cleverly changes "imposter" to "impasta," directly relating it to the character in the joke – a piece of **pasta**.\n\n**So, the joke implies:** The pasta was an "imposter" – not genuine, perhaps deceitful, or simply not who the sauce thought he was. The absurdity of a pasta being an "imposter" and having relationship problems is what makes it a silly, lighthearted pun.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\n\nBecause it kneaded the dough!', 'explanation': 'This is a classic pun! The humor comes from the phrase "**kneaded the dough**," which has two different meanings that sound almost identical:\n\n1.  **"Kneaded the dough" (pizza-making context):** When you make pizza (or bread), you **knead** the **dough**. This is the process of pressing, folding, and stretching the mixture of flour and water to develop its gluten and give it texture. So, a pizza (or the ingredients for it) is inherently associated with the act of kneading dough.\n\n2.  **"Needed the dough" (slang context):** This is where the pun kicks in. The word "**kneaded**" sounds exactly like "**needed**" (past tense of \'to need,\' meaning to require something). And "**dough**" is a common slang term for **money**. So, "needed the dough" means "needed money."\n\nThe joke works because it gives the inanimate pizza a human-like motivation for getting a job (needing money), but frames it using a phrase that literally describes a process involved in making pizza. The unexpected twist and the clever play on words are what make it funny.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a050-07a4-6f4f-8002-241c88af6094'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-03-27T17:47:19.641479+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a04f-cb7e-655b-8001-d7c1cf2b0f82'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\n\nBecause it kneaded the dough!', 'explanation': 'This is a classic pun! The humor comes from the phrase "**kneaded the dough**," which has two different meanings that sound almost identical:\n\n1.  **"Kneaded the dough" (pizza-making context):** When you make pizza (or bread), you **knead** the **dough**. This is the process of pressing, folding, and stretching the mixture of flour and water to develop its gluten and give it texture. So, a pizza (or the ingredients for it) is inherently associated with the act of kneading dough.\n\n2.  **"Needed the dough" (slang context):** This is where the pun kicks in. The word "**kneaded**" sounds exactly like "**needed**" (past tense of \'to need,\' meaning to require something). And "**dough**" is a common slang term for **money**. So, "needed the dough" means "needed money."\n\nThe joke works because it gives the inanimate pizza a human-like motivation for getting a job (needing money), but frames it using a phrase that literally describes a process involved in making pizza. The unexpected twist and the clever play on words are what make it funny.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a050-07a4-6f4f-8002-241c88af6094'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-03-27T17:47:19.641479+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a04f-cb7e-655b-8001-d7c1cf2b0f82'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\n\nBecause it kneaded the dough!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a04f-cb7e-655b-8001-d7c1cf2b0f82'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-03-27T17:47:13.334204+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a04f-6ac9-6f7d-8000-562f0cf0780b'}}, tasks=(PregelTask(id='6f1e42ab-3104-96e7-d068-06e55e7cc23c', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This is a classic pun! The humor comes from the phrase "**kneaded the dough**," which has two different meanings that sound almost identical:\n\n1.  **"Kneaded the dough" (pizza-making context):** When you make pizza (or bread), you **knead** the **dough**. This is the process of pressing, folding, and stretching the mixture of flour and water to develop its gluten and give it texture. So, a pizza (or the ingredients for it) is inherently associated with the act of kneading dough.\n\n2.  **"Needed the dough" (slang context):** This is where the pun kicks in. The word "**kneaded**" sounds exactly like "**needed**" (past tense of \'to need,\' meaning to require something). And "**dough**" is a common slang term for **money**. So, "needed the dough" means "needed money."\n\nThe joke works because it gives the inanimate pizza a human-like motivation for getting a job (needing money), but frames it using a phrase that literally describes a process involved in making pizza. The unexpected twist and the clever play on words are what make it funny.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a04f-6ac9-6f7d-8000-562f0cf0780b'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-03-27T17:47:03.193996+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a04f-6abd-6a59-bfff-1d075d479032'}}, tasks=(PregelTask(id='bf53d956-c17f-91ab-f620-2ca3fb4f2f1f', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza get a job?\n\nBecause it kneaded the dough!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a04f-6abd-6a59-bfff-1d075d479032'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-03-27T17:47:03.188949+00:00', parent_config=None, tasks=(PregelTask(id='9abb097c-4c7a-e990-5d0b-efe986401adb', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %% [markdown]
# # Time Travel

# %%
workflow.get_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f12a04f-cb7e-655b-8001-d7c1cf2b0f82"}})
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\n\nBecause it kneaded the dough!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_id': '1f12a04f-cb7e-655b-8001-d7c1cf2b0f82'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-03-27T17:47:13.334204+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a04f-6ac9-6f7d-8000-562f0cf0780b'}}, tasks=(PregelTask(id='6f1e42ab-3104-96e7-d068-06e55e7cc23c', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This is a classic pun! The humor comes from the phrase "**kneaded the dough**," which has two different meanings that sound almost identical:\n\n1.  **"Kneaded the dough" (pizza-making context):** When you make pizza (or bread), you **knead** the **dough**. This is the process of pressing, folding, and stretching the mixture of flour and water to develop its gluten and give it texture. So, a pizza (or the ingredients for it) is inherently associated with the act of kneading dough.\n\n2.  **"Needed the dough" (slang context):** This is where the pun kicks in. The word "**kneaded**" sounds exactly like "**needed**" (past tense of \'to need,\' meaning to require something). And "**dough**" is a common slang term for **money**. So, "needed the dough" means "needed money."\n\nThe joke works because it gives the inanimate pizza a human-like motivation for getting a job (needing money), but frames it using a phrase that literally describes a process involved in making pizza. The unexpected twist and the clever play on words are what make it funny.'}),), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\n\nBecause it kneaded the dough!', 'explanation': 'This is a classic pun! The humor comes from the phrase "**kneaded the dough**," which has two different meanings that sound almost identical:\n\n1.  **"Kneaded the dough" (pizza-making context):** When you make pizza (or bread), you **knead** the **dough**. This is the process of pressing, folding, and stretching the mixture of flour and water to develop its gluten and give it texture. So, a pizza (or the ingredients for it) is inherently associated with the act of kneading dough.\n\n2.  **"Needed the dough" (slang context):** This is where the pun kicks in. The word "**kneaded**" sounds exactly like "**needed**" (past tense of \'to need,\' meaning to require something). And "**dough**" is a common slang term for **money**. So, "needed the dough" means "needed money."\n\nThe joke works because it gives the inanimate pizza a human-like motivation for getting a job (needing money), but frames it using a phrase that literally describes a process involved in making pizza. The unexpected twist and the clever play on words are what make it funny.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a050-07a4-6f4f-8002-241c88af6094'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-03-27T17:47:19.641479+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a04f-cb7e-655b-8001-d7c1cf2b0f82'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\n\nBecause it kneaded the dough!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a04f-cb7e-655b-8001-d7c1cf2b0f82'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-03-27T17:47:13.334204+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a04f-6ac9-6f7d-8000-562f0cf0780b'}}, tasks=(PregelTask(id='6f1e42ab-3104-96e7-d068-06e55e7cc23c', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This is a classic pun! The humor comes from the phrase "**kneaded the dough**," which has two different meanings that sound almost identical:\n\n1.  **"Kneaded the dough" (pizza-making context):** When you make pizza (or bread), you **knead** the **dough**. This is the process of pressing, folding, and stretching the mixture of flour and water to develop its gluten and give it texture. So, a pizza (or the ingredients for it) is inherently associated with the act of kneading dough.\n\n2.  **"Needed the dough" (slang context):** This is where the pun kicks in. The word "**kneaded**" sounds exactly like "**needed**" (past tense of \'to need,\' meaning to require something). And "**dough**" is a common slang term for **money**. So, "needed the dough" means "needed money."\n\nThe joke works because it gives the inanimate pizza a human-like motivation for getting a job (needing money), but frames it using a phrase that literally describes a process involved in making pizza. The unexpected twist and the clever play on words are what make it funny.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a04f-6ac9-6f7d-8000-562f0cf0780b'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-03-27T17:47:03.193996+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a04f-6abd-6a59-bfff-1d075d479032'}}, tasks=(PregelTask(id='bf53d956-c17f-91ab-f620-2ca3fb4f2f1f', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza get a job?\n\nBecause it kneaded the dough!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a04f-6abd-6a59-bfff-1d075d479032'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-03-27T17:47:03.188949+00:00', parent_config=None, tasks=(PregelTask(id='9abb097c-4c7a-e990-5d0b-efe986401adb', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]
