# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
load_dotenv()
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.7)

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'pizza'}, config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why did the pizza get a job?\n\nBecause it kneaded dough!',
#  'explanation': 'This joke is a pun, playing on two different meanings of the phrase "kneaded dough."\n\nHere\'s the breakdown:\n\n1.  **The literal, pizza-related meaning:**\n    *   Pizza is made from dough.\n    *   To prepare pizza, you have to **knead** the dough (mix and work it with your hands). So, a pizza literally "kneads dough" as part of its creation.\n\n2.  **The pun/figurative meaning:**\n    *   The word "**kneaded**" sounds exactly like "**needed**."\n    *   The word "**dough**" is a common slang term for **money**.\n    *   Therefore, "it kneaded dough" sounds like "it *needed* dough," meaning "it *needed money*."\n\n**How the joke works:**\n\nThe humor comes from the unexpected twist. When you hear "Why did the pizza get a job?", you\'re expecting a human-like reason for employment (like needing money). The punchline delivers that human-like reason ("it needed money"), but it cleverly disguises it using a phrase that also has a literal, absurd meaning in the context of a pizza.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\n\nBecause it kneaded dough!', 'explanation': 'This joke is a pun, playing on two different meanings of the phrase "kneaded dough."\n\nHere\'s the breakdown:\n\n1.  **The literal, pizza-related meaning:**\n    *   Pizza is made from dough.\n    *   To prepare pizza, you have to **knead** the dough (mix and work it with your hands). So, a pizza literally "kneads dough" as part of its creation.\n\n2.  **The pun/figurative meaning:**\n    *   The word "**kneaded**" sounds exactly like "**needed**."\n    *   The word "**dough**" is a common slang term for **money**.\n    *   Therefore, "it kneaded dough" sounds like "it *needed* dough," meaning "it *needed money*."\n\n**How the joke works:**\n\nThe humor comes from the unexpected twist. When you hear "Why did the pizza get a job?", you\'re expecting a human-like reason for employment (like needing money). The punchline delivers that human-like reason ("it needed money"), but it cleverly disguises it using a phrase that also has a literal, absurd meaning in the context of a pizza.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-e96a-69ed-8002-82a620c0beb8'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-03-28T01:20:28.983550+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-b1a0-6367-8001-a58510532490'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\n\nBecause it kneaded dough!', 'explanation': 'This joke is a pun, playing on two different meanings of the phrase "kneaded dough."\n\nHere\'s the breakdown:\n\n1.  **The literal, pizza-related meaning:**\n    *   Pizza is made from dough.\n    *   To prepare pizza, you have to **knead** the dough (mix and work it with your hands). So, a pizza literally "kneads dough" as part of its creation.\n\n2.  **The pun/figurative meaning:**\n    *   The word "**kneaded**" sounds exactly like "**needed**."\n    *   The word "**dough**" is a common slang term for **money**.\n    *   Therefore, "it kneaded dough" sounds like "it *needed* dough," meaning "it *needed money*."\n\n**How the joke works:**\n\nThe humor comes from the unexpected twist. When you hear "Why did the pizza get a job?", you\'re expecting a human-like reason for employment (like needing money). The punchline delivers that human-like reason ("it needed money"), but it cleverly disguises it using a phrase that also has a literal, absurd meaning in the context of a pizza.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-e96a-69ed-8002-82a620c0beb8'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-03-28T01:20:28.983550+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-b1a0-6367-8001-a58510532490'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\n\nBecause it kneaded dough!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-b1a0-6367-8001-a58510532490'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-03-28T01:20:23.133475+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-65e3-6831-8000-f8bcba8ddebe'}}, tasks=(PregelTask(id='b745b3c2-8d5c-f761-942a-82342cb3fe47', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a pun, playing on two different meanings of the phrase "kneaded dough."\n\nHere\'s the breakdown:\n\n1.  **The literal, pizza-related meaning:**\n    *   Pizza is made from dough.\n    *   To prepare pizza, you have to **knead** the dough (mix and work it with your hands). So, a pizza literally "kneads dough" as part of its creation.\n\n2.  **The pun/figurative meaning:**\n    *   The word "**kneaded**" sounds exactly like "**needed**."\n    *   The word "**dough**" is a common slang term for **money**.\n    *   Therefore, "it kneaded dough" sounds like "it *needed* dough," meaning "it *needed money*."\n\n**How the joke works:**\n\nThe humor comes from the unexpected twist. When you hear "Why did the pizza get a job?", you\'re expecting a human-like reason for employment (like needing money). The punchline delivers that human-like reason ("it needed money"), but it cleverly disguises it using a phrase that also has a literal, absurd meaning in the context of a pizza.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-65e3-6831-8000-f8bcba8ddebe'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-03-28T01:20:15.191864+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-65db-6300-bfff-5bbdf4575cb6'}}, tasks=(PregelTask(id='99e1b188-d2dc-e64f-5534-e545655a9e07', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza get a job?\n\nBecause it kneaded dough!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-65db-6300-bfff-5bbdf4575cb6'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-03-28T01:20:15.188454+00:00', parent_config=None, tasks=(PregelTask(id='6f209a1b-6cc3-688f-f81f-b291ef081e1c', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'pasta'}, config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the pasta get arrested?\n\nBecause it was an **impasta**!',
#  'explanation': 'This joke is a classic example of a **pun**! It plays on the similarity in sound between two words:\n\n1.  **Impasta** (the punchline)\n2.  **Impostor** (the word it sounds like)\n\nHere\'s the breakdown:\n\n*   **What an "impostor" is:** An impostor is someone who pretends to be someone else in order to deceive others. They might fake an identity, a role, or a skill. Being an impostor can lead to serious legal trouble, which is why they might get "arrested."\n*   **The pun:** The word "impasta" is created by taking the word "pasta" (the subject of the joke) and making it sound like "impostor."\n*   **Putting it together:** The joke sets up the scenario of *pasta* getting arrested. The punchline "Because it was an **impasta**!" makes us connect the idea of pasta with the crime of being an impostor, simply because the words sound almost identical.\n\nThe humor lies in the unexpected twist and the clever wordplay, applying a human (and criminal) characteristic to an inanimate food item through a linguistic trick.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\n\nBecause it kneaded dough!', 'explanation': 'This joke is a pun, playing on two different meanings of the phrase "kneaded dough."\n\nHere\'s the breakdown:\n\n1.  **The literal, pizza-related meaning:**\n    *   Pizza is made from dough.\n    *   To prepare pizza, you have to **knead** the dough (mix and work it with your hands). So, a pizza literally "kneads dough" as part of its creation.\n\n2.  **The pun/figurative meaning:**\n    *   The word "**kneaded**" sounds exactly like "**needed**."\n    *   The word "**dough**" is a common slang term for **money**.\n    *   Therefore, "it kneaded dough" sounds like "it *needed* dough," meaning "it *needed money*."\n\n**How the joke works:**\n\nThe humor comes from the unexpected twist. When you hear "Why did the pizza get a job?", you\'re expecting a human-like reason for employment (like needing money). The punchline delivers that human-like reason ("it needed money"), but it cleverly disguises it using a phrase that also has a literal, absurd meaning in the context of a pizza.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-e96a-69ed-8002-82a620c0beb8'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-03-28T01:20:28.983550+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-b1a0-6367-8001-a58510532490'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\n\nBecause it kneaded dough!', 'explanation': 'This joke is a pun, playing on two different meanings of the phrase "kneaded dough."\n\nHere\'s the breakdown:\n\n1.  **The literal, pizza-related meaning:**\n    *   Pizza is made from dough.\n    *   To prepare pizza, you have to **knead** the dough (mix and work it with your hands). So, a pizza literally "kneads dough" as part of its creation.\n\n2.  **The pun/figurative meaning:**\n    *   The word "**kneaded**" sounds exactly like "**needed**."\n    *   The word "**dough**" is a common slang term for **money**.\n    *   Therefore, "it kneaded dough" sounds like "it *needed* dough," meaning "it *needed money*."\n\n**How the joke works:**\n\nThe humor comes from the unexpected twist. When you hear "Why did the pizza get a job?", you\'re expecting a human-like reason for employment (like needing money). The punchline delivers that human-like reason ("it needed money"), but it cleverly disguises it using a phrase that also has a literal, absurd meaning in the context of a pizza.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-e96a-69ed-8002-82a620c0beb8'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-03-28T01:20:28.983550+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-b1a0-6367-8001-a58510532490'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\n\nBecause it kneaded dough!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-b1a0-6367-8001-a58510532490'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-03-28T01:20:23.133475+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-65e3-6831-8000-f8bcba8ddebe'}}, tasks=(PregelTask(id='b745b3c2-8d5c-f761-942a-82342cb3fe47', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a pun, playing on two different meanings of the phrase "kneaded dough."\n\nHere\'s the breakdown:\n\n1.  **The literal, pizza-related meaning:**\n    *   Pizza is made from dough.\n    *   To prepare pizza, you have to **knead** the dough (mix and work it with your hands). So, a pizza literally "kneads dough" as part of its creation.\n\n2.  **The pun/figurative meaning:**\n    *   The word "**kneaded**" sounds exactly like "**needed**."\n    *   The word "**dough**" is a common slang term for **money**.\n    *   Therefore, "it kneaded dough" sounds like "it *needed* dough," meaning "it *needed money*."\n\n**How the joke works:**\n\nThe humor comes from the unexpected twist. When you hear "Why did the pizza get a job?", you\'re expecting a human-like reason for employment (like needing money). The punchline delivers that human-like reason ("it needed money"), but it cleverly disguises it using a phrase that also has a literal, absurd meaning in the context of a pizza.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-65e3-6831-8000-f8bcba8ddebe'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-03-28T01:20:15.191864+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-65db-6300-bfff-5bbdf4575cb6'}}, tasks=(PregelTask(id='99e1b188-d2dc-e64f-5534-e545655a9e07', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza get a job?\n\nBecause it kneaded dough!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-65db-6300-bfff-5bbdf4575cb6'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-03-28T01:20:15.188454+00:00', parent_config=None, tasks=(PregelTask(id='6f209a1b-6cc3-688f-f81f-b291ef081e1c', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %% [markdown]
# # Time Travel

# %%
workflow.get_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f12a04f-cb7e-655b-8001-d7c1cf2b0f82"}})
# Out:
# StateSnapshot(values={}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_id': '1f12a04f-cb7e-655b-8001-d7c1cf2b0f82'}}, metadata=None, created_at=None, parent_config=None, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\n\nBecause it kneaded dough!', 'explanation': 'This joke is a pun, playing on two different meanings of the phrase "kneaded dough."\n\nHere\'s the breakdown:\n\n1.  **The literal, pizza-related meaning:**\n    *   Pizza is made from dough.\n    *   To prepare pizza, you have to **knead** the dough (mix and work it with your hands). So, a pizza literally "kneads dough" as part of its creation.\n\n2.  **The pun/figurative meaning:**\n    *   The word "**kneaded**" sounds exactly like "**needed**."\n    *   The word "**dough**" is a common slang term for **money**.\n    *   Therefore, "it kneaded dough" sounds like "it *needed* dough," meaning "it *needed money*."\n\n**How the joke works:**\n\nThe humor comes from the unexpected twist. When you hear "Why did the pizza get a job?", you\'re expecting a human-like reason for employment (like needing money). The punchline delivers that human-like reason ("it needed money"), but it cleverly disguises it using a phrase that also has a literal, absurd meaning in the context of a pizza.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-e96a-69ed-8002-82a620c0beb8'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-03-28T01:20:28.983550+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-b1a0-6367-8001-a58510532490'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\n\nBecause it kneaded dough!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-b1a0-6367-8001-a58510532490'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-03-28T01:20:23.133475+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-65e3-6831-8000-f8bcba8ddebe'}}, tasks=(PregelTask(id='b745b3c2-8d5c-f761-942a-82342cb3fe47', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a pun, playing on two different meanings of the phrase "kneaded dough."\n\nHere\'s the breakdown:\n\n1.  **The literal, pizza-related meaning:**\n    *   Pizza is made from dough.\n    *   To prepare pizza, you have to **knead** the dough (mix and work it with your hands). So, a pizza literally "kneads dough" as part of its creation.\n\n2.  **The pun/figurative meaning:**\n    *   The word "**kneaded**" sounds exactly like "**needed**."\n    *   The word "**dough**" is a common slang term for **money**.\n    *   Therefore, "it kneaded dough" sounds like "it *needed* dough," meaning "it *needed money*."\n\n**How the joke works:**\n\nThe humor comes from the unexpected twist. When you hear "Why did the pizza get a job?", you\'re expecting a human-like reason for employment (like needing money). The punchline delivers that human-like reason ("it needed money"), but it cleverly disguises it using a phrase that also has a literal, absurd meaning in the context of a pizza.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-65e3-6831-8000-f8bcba8ddebe'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-03-28T01:20:15.191864+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-65db-6300-bfff-5bbdf4575cb6'}}, tasks=(PregelTask(id='99e1b188-d2dc-e64f-5534-e545655a9e07', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza get a job?\n\nBecause it kneaded dough!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-65db-6300-bfff-5bbdf4575cb6'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-03-28T01:20:15.188454+00:00', parent_config=None, tasks=(PregelTask(id='6f209a1b-6cc3-688f-f81f-b291ef081e1c', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %% [markdown]
# # Updating State

# %%
workflow.update_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f12a04f-cb7e-655b-8001-d7c1cf2b0f82", "checkpoint_ns": ""}}, {'topic':'rosogolla'})
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f12a446-3e8b-6a47-8000-dcc27894a75a'}}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'rosogolla'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a446-3e8b-6a47-8000-dcc27894a75a'}}, metadata={'source': 'update', 'step': 0, 'parents': {}}, created_at='2026-03-28T01:21:04.753517+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a04f-cb7e-655b-8001-d7c1cf2b0f82'}}, tasks=(PregelTask(id='ef948146-4f9b-3d57-3648-4ee809ba11b0', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\n\nBecause it kneaded dough!', 'explanation': 'This joke is a pun, playing on two different meanings of the phrase "kneaded dough."\n\nHere\'s the breakdown:\n\n1.  **The literal, pizza-related meaning:**\n    *   Pizza is made from dough.\n    *   To prepare pizza, you have to **knead** the dough (mix and work it with your hands). So, a pizza literally "kneads dough" as part of its creation.\n\n2.  **The pun/figurative meaning:**\n    *   The word "**kneaded**" sounds exactly like "**needed**."\n    *   The word "**dough**" is a common slang term for **money**.\n    *   Therefore, "it kneaded dough" sounds like "it *needed* dough," meaning "it *needed money*."\n\n**How the joke works:**\n\nThe humor comes from the unexpected twist. When you hear "Why did the pizza get a job?", you\'re expecting a human-like reason for employment (like needing money). The punchline delivers that human-like reason ("it needed money"), but it cleverly disguises it using a phrase that also has a literal, absurd meaning in the context of a pizza.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-e96a-69ed-8002-82a620c0beb8'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-03-28T01:20:28.983550+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-b1a0-6367-8001-a58510532490'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\n\nBecause it kneaded dough!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-b1a0-6367-8001-a58510532490'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-03-28T01:20:23.133475+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-65e3-6831-8000-f8bcba8ddebe'}}, tasks=(PregelTask(id='b745b3c2-8d5c-f761-942a-82342cb3fe47', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a pun, playing on two different meanings of the phrase "kneaded dough."\n\nHere\'s the breakdown:\n\n1.  **The literal, pizza-related meaning:**\n    *   Pizza is made from dough.\n    *   To prepare pizza, you have to **knead** the dough (mix and work it with your hands). So, a pizza literally "kneads dough" as part of its creation.\n\n2.  **The pun/figurative meaning:**\n    *   The word "**kneaded**" sounds exactly like "**needed**."\n    *   The word "**dough**" is a common slang term for **money**.\n    *   Therefore, "it kneaded dough" sounds like "it *needed* dough," meaning "it *needed money*."\n\n**How the joke works:**\n\nThe humor comes from the unexpected twist. When you hear "Why did the pizza get a job?", you\'re expecting a human-like reason for employment (like needing money). The punchline delivers that human-like reason ("it needed money"), but it cleverly disguises it using a phrase that also has a literal, absurd meaning in the context of a pizza.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-65e3-6831-8000-f8bcba8ddebe'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-03-28T01:20:15.191864+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-65db-6300-bfff-5bbdf4575cb6'}}, tasks=(PregelTask(id='99e1b188-d2dc-e64f-5534-e545655a9e07', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza get a job?\n\nBecause it kneaded dough!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-65db-6300-bfff-5bbdf4575cb6'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-03-28T01:20:15.188454+00:00', parent_config=None, tasks=(PregelTask(id='6f209a1b-6cc3-688f-f81f-b291ef081e1c', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f12a446-3e8b-6a47-8000-dcc27894a75a"}})
# Out:
# {'topic': 'rosogolla',
#  'joke': 'Why did the Rosogolla get a promotion?\n\nBecause it was always *soaked* in its work and *full* of sweet ideas!',
#  'explanation': 'This joke is a classic example of a **pun**, playing on the double meanings of words and phrases related to both human work ethic and the physical characteristics of a Rosogolla.\n\nHere\'s the breakdown:\n\n1.  **"soaked in its work"**:\n    *   **For a person (idiomatic meaning):** This phrase means someone is deeply immersed, dedicated, and very committed to their job. They put a lot of effort and time into it.\n    *   **For a Rosogolla (literal meaning):** A Rosogolla is a sweet that is literally *soaked* in sugar syrup (chashni). This is its defining characteristic!\n\n2.  **"full of sweet ideas!"**:\n    *   **For a person (idiomatic meaning):** To be "full of sweet ideas" means to have many good, clever, appealing, or successful ideas that are beneficial or pleasant. "Sweet" here means excellent or desirable.\n    *   **For a Rosogolla (literal meaning):** A Rosogolla is a sweet dish, and it is literally "full" of sweetness (from the syrup it\'s soaked in and its ingredients).\n\nThe humor comes from the clever way the joke applies human work traits to a Rosogolla, using words that have both a metaphorical meaning in a work context and a literal, descriptive meaning for the sweet itself. It\'s a delicious play on words!'}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'rosogolla', 'joke': 'Why did the Rosogolla get a promotion?\n\nBecause it was always *soaked* in its work and *full* of sweet ideas!', 'explanation': 'This joke is a classic example of a **pun**, playing on the double meanings of words and phrases related to both human work ethic and the physical characteristics of a Rosogolla.\n\nHere\'s the breakdown:\n\n1.  **"soaked in its work"**:\n    *   **For a person (idiomatic meaning):** This phrase means someone is deeply immersed, dedicated, and very committed to their job. They put a lot of effort and time into it.\n    *   **For a Rosogolla (literal meaning):** A Rosogolla is a sweet that is literally *soaked* in sugar syrup (chashni). This is its defining characteristic!\n\n2.  **"full of sweet ideas!"**:\n    *   **For a person (idiomatic meaning):** To be "full of sweet ideas" means to have many good, clever, appealing, or successful ideas that are beneficial or pleasant. "Sweet" here means excellent or desirable.\n    *   **For a Rosogolla (literal meaning):** A Rosogolla is a sweet dish, and it is literally "full" of sweetness (from the syrup it\'s soaked in and its ingredients).\n\nThe humor comes from the clever way the joke applies human work traits to a Rosogolla, using words that have both a metaphorical meaning in a work context and a literal, descriptive meaning for the sweet itself. It\'s a delicious play on words!'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a449-1680-64ad-8002-ed8f5a649e48'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-03-28T01:22:21.085201+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a448-d875-66d9-8001-81780de0d3ea'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'rosogolla', 'joke': 'Why did the Rosogolla get a promotion?\n\nBecause it was always *soaked* in its work and *full* of sweet ideas!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a448-d875-66d9-8001-81780de0d3ea'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-03-28T01:22:14.579580+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a446-3e8b-6a47-8000-dcc27894a75a'}}, tasks=(PregelTask(id='2bdc1976-1229-d839-b411-c4100e60bfe6', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a classic example of a **pun**, playing on the double meanings of words and phrases related to both human work ethic and the physical characteristics of a Rosogolla.\n\nHere\'s the breakdown:\n\n1.  **"soaked in its work"**:\n    *   **For a person (idiomatic meaning):** This phrase means someone is deeply immersed, dedicated, and very committed to their job. They put a lot of effort and time into it.\n    *   **For a Rosogolla (literal meaning):** A Rosogolla is a sweet that is literally *soaked* in sugar syrup (chashni). This is its defining characteristic!\n\n2.  **"full of sweet ideas!"**:\n    *   **For a person (idiomatic meaning):** To be "full of sweet ideas" means to have many good, clever, appealing, or successful ideas that are beneficial or pleasant. "Sweet" here means excellent or desirable.\n    *   **For a Rosogolla (literal meaning):** A Rosogolla is a sweet dish, and it is literally "full" of sweetness (from the syrup it\'s soaked in and its ingredients).\n\nThe humor comes from the clever way the joke applies human work traits to a Rosogolla, using words that have both a metaphorical meaning in a work context and a literal, descriptive meaning for the sweet itself. It\'s a delicious play on words!'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'rosogolla'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a446-3e8b-6a47-8000-dcc27894a75a'}}, metadata={'source': 'update', 'step': 0, 'parents': {}}, created_at='2026-03-28T01:21:04.753517+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a04f-cb7e-655b-8001-d7c1cf2b0f82'}}, tasks=(PregelTask(id='ef948146-4f9b-3d57-3648-4ee809ba11b0', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the Rosogolla get a promotion?\n\nBecause it was always *soaked* in its work and *full* of sweet ideas!'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\n\nBecause it kneaded dough!', 'explanation': 'This joke is a pun, playing on two different meanings of the phrase "kneaded dough."\n\nHere\'s the breakdown:\n\n1.  **The literal, pizza-related meaning:**\n    *   Pizza is made from dough.\n    *   To prepare pizza, you have to **knead** the dough (mix and work it with your hands). So, a pizza literally "kneads dough" as part of its creation.\n\n2.  **The pun/figurative meaning:**\n    *   The word "**kneaded**" sounds exactly like "**needed**."\n    *   The word "**dough**" is a common slang term for **money**.\n    *   Therefore, "it kneaded dough" sounds like "it *needed* dough," meaning "it *needed money*."\n\n**How the joke works:**\n\nThe humor comes from the unexpected twist. When you hear "Why did the pizza get a job?", you\'re expecting a human-like reason for employment (like needing money). The punchline delivers that human-like reason ("it needed money"), but it cleverly disguises it using a phrase that also has a literal, absurd meaning in the context of a pizza.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-e96a-69ed-8002-82a620c0beb8'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-03-28T01:20:28.983550+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-b1a0-6367-8001-a58510532490'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\n\nBecause it kneaded dough!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-b1a0-6367-8001-a58510532490'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-03-28T01:20:23.133475+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-65e3-6831-8000-f8bcba8ddebe'}}, tasks=(PregelTask(id='b745b3c2-8d5c-f761-942a-82342cb3fe47', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a pun, playing on two different meanings of the phrase "kneaded dough."\n\nHere\'s the breakdown:\n\n1.  **The literal, pizza-related meaning:**\n    *   Pizza is made from dough.\n    *   To prepare pizza, you have to **knead** the dough (mix and work it with your hands). So, a pizza literally "kneads dough" as part of its creation.\n\n2.  **The pun/figurative meaning:**\n    *   The word "**kneaded**" sounds exactly like "**needed**."\n    *   The word "**dough**" is a common slang term for **money**.\n    *   Therefore, "it kneaded dough" sounds like "it *needed* dough," meaning "it *needed money*."\n\n**How the joke works:**\n\nThe humor comes from the unexpected twist. When you hear "Why did the pizza get a job?", you\'re expecting a human-like reason for employment (like needing money). The punchline delivers that human-like reason ("it needed money"), but it cleverly disguises it using a phrase that also has a literal, absurd meaning in the context of a pizza.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-65e3-6831-8000-f8bcba8ddebe'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-03-28T01:20:15.191864+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-65db-6300-bfff-5bbdf4575cb6'}}, tasks=(PregelTask(id='99e1b188-d2dc-e64f-5534-e545655a9e07', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza get a job?\n\nBecause it kneaded dough!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f12a444-65db-6300-bfff-5bbdf4575cb6'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-03-28T01:20:15.188454+00:00', parent_config=None, tasks=(PregelTask(id='6f209a1b-6cc3-688f-f81f-b291ef081e1c', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %% [markdown]
# # Fault Tolerance

# %%
from langgraph.graph import StateGraph, END
from langgraph.checkpoint.memory import InMemorySaver
from typing import TypedDict
import time

# %%
# 1. Define the state
class CrashState(TypedDict):
    input: str
    step1: str
    step2: str

# %%
# 2. Define steps
def step_1(state: CrashState) -> CrashState:
    print(" Step 1 executed")
    return {"step1": "done", "input": state["input"]}

def step_2(state: CrashState) -> CrashState:
    print(" Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)")
    time.sleep(1000)  # Simulate long-running hang
    return {"step2": "done"}

def step_3(state: CrashState) -> CrashState:
    print(" Step 3 executed")
    return {"done": True}

# %%
# 3. Build the graph
builder = StateGraph(CrashState)
builder.add_node("step_1", step_1)
builder.add_node("step_2", step_2)
builder.add_node("step_3", step_3)

builder.set_entry_point("step_1")
builder.add_edge("step_1", "step_2")
builder.add_edge("step_2", "step_3")
builder.add_edge("step_3", END)

checkpointer = InMemorySaver()
graph = builder.compile(checkpointer=checkpointer)

# %%
try:
    print(" Running graph: Please manually interrupt during Step 2...")
    graph.invoke({"input": "start"}, config={"configurable": {"thread_id": 'thread-1'}})
except KeyboardInterrupt:
    print(" Kernel manually interrupted (crash simulated).")
# Out:
# ▶️ Running graph: Please manually interrupt during Step 2...
# ✅ Step 1 executed
# ⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)
# ❌ Kernel manually interrupted (crash simulated).

# %%
# 6. Re-run to show fault-tolerant resume
print("\n Re-running the graph to demonstrate fault tolerance...")
final_state = graph.invoke(None, config={"configurable": {"thread_id": 'thread-1'}})
print("\n Final State:", final_state)
